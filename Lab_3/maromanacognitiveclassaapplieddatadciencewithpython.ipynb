# %% [markdown]
# **Certificados Laboratorio 3**
#
# Link de Linkedlin www.linkedin.com/in/mapu-romi
# ![Linkedin captura.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
# ![maromanacognitiveclassaappliedpythonfordatascience.jpg](data:image/jpeg;base64,...)
